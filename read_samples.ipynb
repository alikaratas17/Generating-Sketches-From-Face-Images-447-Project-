# %%
import pickle

# %%
import numpy
import matplotlib.pyplot as plt

# %%
# !ls samples4
# Out:
# xA_samples.pickle xB_samples.pickle yA_samples.pickle yB_samples.pickle

# %%
with open("samples3/xA_samples.pickle" , "rb") as f: #change xA to yB (for B domain)
    x_samples = pickle.load(f)

# %%
x_samples.shape
# Out:
# (16, 3, 256, 256)

# %%
with open("samples3/yA_samples.pickle" , "rb") as f: #change yA to xB (for B domain)
    y_samples = pickle.load(f)

# %%
y_samples.shape
# Out:
# (16, 1, 256, 256)

# %%
x_samples = numpy.moveaxis(x_samples, 1,3)

# %%
i = 0

# %%
y_samples.shape
# Out:
# (16, 1, 256, 256)

# %%
y_samples.min()
# Out:
# 0.0

# %%
y_samples.max()
# Out:
# 1.0

# %%
plt.imshow(y_samples[i,0,:,:],cmap="gray")

# %%
plt.imshow(x_samples[i,:,:,:])

# %%
i += 1

# %%
i
# Out:
# 1
